# %%
PSNR AND THE SSIM FOR THE ORGINAL VIDEO AND THE OUTPUT VIDEO

# %%
import cv2
import numpy as np
import tensorflow as tf
import os
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import mean_squared_error

def build_generator():
    """ Define a simple CNN generator for watermark prediction """
    inputs = tf.keras.layers.Input(shape=(128, 128, 1))
    x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
    model = tf.keras.Model(inputs, x, name="Generator")
    return model

generator = build_generator()
weights_path = "./model_weights/generator_epoch_4900.weights.h5"

if os.path.exists(weights_path):
    generator.load_weights(weights_path)
    print("✅ Generator weights loaded successfully!")
else:
    raise FileNotFoundError(f"❌ Weights file not found at {weights_path}")

INPUT_VIDEO_PATH = "./input1.mp4"
OUTPUT_VIDEO_PATH = "./output_watermarked1.mp4"


cap = cv2.VideoCapture(INPUT_VIDEO_PATH)

fps = int(cap.get(cv2.CAP_PROP_FPS))
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

out = cv2.VideoWriter(OUTPUT_VIDEO_PATH, fourcc, fps, (frame_width, frame_height))

frame_count = 0
psnr_values = []
ssim_values = []
alpha = 0.01

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  
    frame = frame.astype(np.float32) / 255.0  
    gray_frame = cv2.cvtColor((frame * 255).astype(np.uint8), cv2.COLOR_BGR2GRAY)
    resized_frame = cv2.resize(gray_frame, (128, 128)) / 255.0  
    input_frame = np.expand_dims(resized_frame, axis=[0, -1])
    watermark = generator.predict(input_frame)[0, :, :, 0]  
    watermark_resized = cv2.resize(watermark, (frame_width, frame_height))

    watermarked_frame = frame + alpha * np.expand_dims(watermark_resized, axis=-1)
    watermarked_frame = np.clip(watermarked_frame * 255, 0, 255).astype(np.uint8)

    out.write(watermarked_frame)

    original_frame = (frame * 255).astype(np.uint8)
    psnr_value = psnr(original_frame, watermarked_frame, data_range=255)
    ssim_value = ssim(original_frame, watermarked_frame, data_range=255, win_size=3, channel_axis=-1)
    psnr_values.append(psnr_value)
    ssim_values.append(ssim_value)
    frame_count += 1

cap.release()
out.release()

avg_psnr = np.mean(psnr_values)
avg_ssim = np.mean(ssim_values)


print(f"✅ Watermarked video saved: {OUTPUT_VIDEO_PATH}")
print(f"📊  PSNR: {avg_psnr:.4f} (More Than 30 is better)")
print(f"📊  SSIM : {avg_ssim:.6f} (Closer to 1 is better)")
# Out:
# ✅ Generator weights loaded successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# ✅ Watermarked video saved: ./output_watermarked1.mp4
# 📊  PSNR: 49.4692 (More Than 30 is better)
# 📊  SSIM : 0.990960 (Closer to 1 is better)

# %%
GAN GENERAED WATERMARK VS EXTRACTED WATERMARK SSIM

# %%
import cv2
import numpy as np
import tensorflow as tf
import os
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import mean_squared_error

def build_generator():
    """ Define a simple CNN generator for watermark prediction """
    inputs = tf.keras.layers.Input(shape=(128, 128, 1))
    x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
    model = tf.keras.Model(inputs, x, name="Generator")
    return model

generator = build_generator()
weights_path = "./model_weights/generator_epoch_4900.weights.h5"

if os.path.exists(weights_path):
    generator.load_weights(weights_path)
    print("✅ Generator weights loaded successfully!")
else:
    raise FileNotFoundError(f"❌ Weights file not found at {weights_path}")

INPUT_VIDEO_PATH = "./input1.mp4"
OUTPUT_VIDEO_PATH = "./output_watermarked1.mp4"
GENERATED_WATERMARK_PATH = "./generated_watermarks"
EXTRACTED_WATERMARK_PATH = "./extracted_watermarks"

os.makedirs(GENERATED_WATERMARK_PATH, exist_ok=True)
os.makedirs(EXTRACTED_WATERMARK_PATH, exist_ok=True)

cap = cv2.VideoCapture(INPUT_VIDEO_PATH)

fps = int(cap.get(cv2.CAP_PROP_FPS))
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

out = cv2.VideoWriter(OUTPUT_VIDEO_PATH, fourcc, fps, (frame_width, frame_height))

frame_count = 0
psnr_values = []
ssim_values = []
watermark_ssim_values = []
watermark_mse_values = []

alpha = 0.07

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  

    frame = frame.astype(np.float32) / 255.0  

    gray_frame = cv2.cvtColor((frame * 255).astype(np.uint8), cv2.COLOR_BGR2GRAY)
    resized_frame = cv2.resize(gray_frame, (128, 128)) / 255.0  

    input_frame = np.expand_dims(resized_frame, axis=[0, -1])
    watermark = generator.predict(input_frame)[0, :, :, 0]  

    watermark_resized = cv2.resize(watermark, (frame_width, frame_height))

    generated_watermark_path = os.path.join(GENERATED_WATERMARK_PATH, f"frame_{frame_count:04d}.png")
    cv2.imwrite(generated_watermark_path, (watermark_resized * 255).astype(np.uint8))

    watermarked_frame = frame + alpha * np.expand_dims(watermark_resized, axis=-1)
    watermarked_frame = np.clip(watermarked_frame * 255, 0, 255).astype(np.uint8)

    out.write(watermarked_frame)

    original_frame = (frame * 255).astype(np.uint8)
    psnr_value = psnr(original_frame, watermarked_frame, data_range=255)
    ssim_value = ssim(original_frame, watermarked_frame, data_range=255, win_size=3, channel_axis=-1)

    psnr_values.append(psnr_value)
    ssim_values.append(ssim_value)

    extracted_watermark = (watermarked_frame.astype(np.float32) - frame * 255) / alpha
    extracted_watermark = np.mean(extracted_watermark, axis=-1) 

    extracted_watermark = cv2.GaussianBlur(extracted_watermark, (3, 3), 0)

    extracted_watermark = np.clip(extracted_watermark, 0, 255).astype(np.uint8)
    
    extracted_watermark_path = os.path.join(EXTRACTED_WATERMARK_PATH, f"frame_{frame_count:04d}.png")
    cv2.imwrite(extracted_watermark_path, extracted_watermark)

    h, w = watermark_resized.shape
    h_start, h_end = h // 4, 3 * h // 4
    w_start, w_end = w // 4, 3 * w // 4
    cropped_original = watermark_resized[h_start:h_end, w_start:w_end]
    cropped_extracted = extracted_watermark[h_start:h_end, w_start:w_end]

    watermark_ssim = ssim(cropped_original, cropped_extracted.astype(np.float32) / 255, data_range=1.0)
    watermark_mse = mean_squared_error(cropped_original.flatten(), cropped_extracted.flatten() / 255)

    watermark_ssim_values.append(watermark_ssim)
    watermark_mse_values.append(watermark_mse)

    frame_count += 1

cap.release()
out.release()

avg_watermark_ssim = np.mean(watermark_ssim_values)
avg_watermark_mse = np.mean(watermark_mse_values)

print(f"✅ Watermarked video saved: {OUTPUT_VIDEO_PATH}")
print(f"✅ Generated watermarks saved in: {GENERATED_WATERMARK_PATH}")
print(f"✅ Extracted watermarks saved in: {EXTRACTED_WATERMARK_PATH}")
print(f"📊 Watermark SSIM: {avg_watermark_ssim:.4f} (Closer to 1 is better)")
print(f"📊 Watermark MSE: {avg_watermark_mse:.6f} (Lower is better)")
print(f"🎯 Model Accuracy (Based on SSIM): {avg_watermark_ssim * 100:.2f}%")
# Out:
# ✅ Generator weights loaded successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ Watermarked video saved: ./output_watermarked1.mp4
# ✅ Generated watermarks saved in: ./generated_watermarks
# ✅ Extracted watermarks saved in: ./extracted_watermarks
# 📊 Watermark SSIM: 0.8691 (Closer to 1 is better)
# 📊 Watermark MSE: 0.000825 (Lower is better)
# 🎯 Model Accuracy (Based on SSIM): 86.91%

# %%
EXTRACT THE WATERMARK FROM THE DEEPFAKED WATERMARK VIDEO

# %%
import cv2
import os
import numpy as np
from skimage.metrics import structural_similarity as ssim

ORIGINAL_VIDEO_PATH = "./input1.mp4"
WATERMARKED_VIDEO_PATH = "./deepfaked.mp4"
EXTRACTED_WATERMARK_PATH = "./deepfaked_extracted_watermarks"

os.makedirs(EXTRACTED_WATERMARK_PATH, exist_ok=True)

cap_original = cv2.VideoCapture(ORIGINAL_VIDEO_PATH)
cap_watermarked = cv2.VideoCapture(WATERMARKED_VIDEO_PATH)

alpha = 0.07 

frame_count = 0
ssim_values = []

while cap_original.isOpened() and cap_watermarked.isOpened():
    ret_orig, frame_orig = cap_original.read()
    ret_watermarked, frame_watermarked = cap_watermarked.read()

    if not ret_orig or not ret_watermarked:
        break 

    frame_orig = frame_orig.astype(np.float32)
    frame_watermarked = frame_watermarked.astype(np.float32)

    extracted_watermark = (frame_watermarked - frame_orig) / alpha

    extracted_watermark = np.mean(extracted_watermark, axis=-1)

    extracted_watermark = cv2.GaussianBlur(extracted_watermark, (3, 3), 0)

    extracted_watermark = np.clip(extracted_watermark, 0, 255).astype(np.uint8)

    extracted_watermark_path = os.path.join(EXTRACTED_WATERMARK_PATH, f"frame_{frame_count:04d}.png")
    cv2.imwrite(extracted_watermark_path, extracted_watermark)

    frame_count += 1

cap_original.release()
cap_watermarked.release()

print(f"✅ Extracted watermarks saved in: {EXTRACTED_WATERMARK_PATH}")
# Out:
# ✅ Extracted watermarks saved in: ./deepfaked_extracted_watermarks

# %%
Calculating the SSIM of the GAN Generated Watermark and the extracted watermark from deepfaked video

# %%
import cv2
import os
import numpy as np
from skimage.metrics import structural_similarity as ssim
from sklearn.metrics import mean_squared_error

GENERATED_WATERMARK_PATH = "./generated_watermarks"
EXTRACTED_WATERMARK_PATH = "./deepfaked_extracted_watermarks"

generated_files = sorted(os.listdir(GENERATED_WATERMARK_PATH))
extracted_files = sorted(os.listdir(EXTRACTED_WATERMARK_PATH))

assert len(generated_files) == len(extracted_files), "Mismatch in number of frames!"

SSIM_THRESHOLD = 0.6
MSE_THRESHOLD = 0.02 

deepfake_frames = 0
total_frames = len(generated_files)
ssim_values = []
mse_values = []

for gen_file, ext_file in zip(generated_files, extracted_files):
    gen_path = os.path.join(GENERATED_WATERMARK_PATH, gen_file)
    ext_path = os.path.join(EXTRACTED_WATERMARK_PATH, ext_file)

    gen_img = cv2.imread(gen_path, cv2.IMREAD_GRAYSCALE) / 255.0  
    ext_img = cv2.imread(ext_path, cv2.IMREAD_GRAYSCALE) / 255.0  

    ssim_value = ssim(gen_img, ext_img, data_range=1.0)
    mse_value = mean_squared_error(gen_img.flatten(), ext_img.flatten())

    ssim_values.append(ssim_value)
    mse_values.append(mse_value)

    if ssim_value < SSIM_THRESHOLD or mse_value > MSE_THRESHOLD:
        deepfake_frames += 1

avg_ssim = np.mean(ssim_values)
avg_mse = np.mean(mse_values)

deepfake_percentage = (deepfake_frames / total_frames) * 100


print(f"📊 Average SSIM: {avg_ssim:.4f} (Closer to 1 is better)")
print(f"📊 Average MSE: {avg_mse:.6f} (Lower is better)")
print(f"🔎 Deepfake Suspicious Frames: {deepfake_frames}/{total_frames} ({deepfake_percentage:.2f}%)")
# Out:
# 📊 Average SSIM: 0.5828 (Closer to 1 is better)
# 📊 Average MSE: 0.027067 (Lower is better)
# 🔎 Deepfake Suspicious Frames: 469/469 (100.00%)

# %%
Extracting the watermark stored in the dwt/dct

# %%
import cv2
import numpy as np
import pywt
import os
from tqdm import tqdm

def extract_watermark_from_image(watermarked_img_path, alpha=0.05, watermark_shape=(50, 50)):
    wm_img = cv2.imread(watermarked_img_path, cv2.IMREAD_GRAYSCALE)
    if wm_img is None:
        raise ValueError(f"Could not load image: {watermarked_img_path}")
    coeffs = pywt.dwt2(wm_img, 'haar')
    LL, (LH, HL, HH) = coeffs
    dct_LL = cv2.dct(np.float32(LL))
    estimated_original = cv2.medianBlur(dct_LL, 5)
    watermark_diff = (dct_LL - estimated_original) / alpha
    watermark = cv2.resize(watermark_diff, watermark_shape)
    watermark = cv2.normalize(watermark, None, 0, 255, cv2.NORM_MINMAX)
    
    return watermark.astype(np.uint8)

def batch_extract_watermarks(input_dir, output_dir, alpha=0.05, watermark_shape=(50, 50)):
    """
    Processes all images in a directory to extract watermarks
    """
    os.makedirs(output_dir, exist_ok=True)
    frame_files = sorted([f for f in os.listdir(input_dir) if f.startswith('frame_') and f.endswith('.png')])
    watermark_accumulator = None
    valid_count = 0
    for frame_file in tqdm(frame_files, desc="Extracting watermarks"):
        try:
            frame_path = os.path.join(input_dir, frame_file)
            wm = extract_watermark_from_image(frame_path, alpha, watermark_shape)
            if watermark_accumulator is None:
                watermark_accumulator = np.zeros_like(wm, dtype=np.float32)
            watermark_accumulator += wm.astype(np.float32)
            valid_count += 1
            output_path = os.path.join(output_dir, f"extracted_{frame_file}")
            cv2.imwrite(output_path, wm)
            
        except Exception as e:
            print(f"Error processing {frame_file}: {str(e)}")
    if valid_count > 0:
        avg_watermark = (watermark_accumulator / valid_count).astype(np.uint8)
        cv2.imwrite(os.path.join(output_dir, "averaged_watermark.png"), avg_watermark)
        print(f"Successfully processed {valid_count} frames. Average watermark saved.")
    else:
        print("No valid frames processed.")

if __name__ == "__main__":
    INPUT_DIR = "./generated_watermarks"  # Folder with your watermarked frames
    OUTPUT_DIR = "./check_generated"  # Where to save extracted watermarks
    ALPHA = 0.05  # Must match your embedding strength
    WATERMARK_SHAPE = (50, 50)  # Must match your original watermark dimensions
    
    # Run extraction
    batch_extract_watermarks(INPUT_DIR, OUTPUT_DIR, ALPHA, WATERMARK_SHAPE)
# Out:
# Extracting watermarks: 100%|█████████████████████████████████████████████████████████| 469/469 [00:06<00:00, 75.00it/s]
# Successfully processed 469 frames. Average watermark saved.

# %%
Extracting the watermark embeded in the deepfaked frame

# %%
import cv2
import numpy as np
import pywt
import os
from tqdm import tqdm

def extract_watermark_from_image(watermarked_img_path, alpha=0.05, watermark_shape=(50, 50)):
    wm_img = cv2.imread(watermarked_img_path, cv2.IMREAD_GRAYSCALE)
    if wm_img is None:
        raise ValueError(f"Could not load image: {watermarked_img_path}")
    coeffs = pywt.dwt2(wm_img, 'haar')
    LL, (LH, HL, HH) = coeffs
    dct_LL = cv2.dct(np.float32(LL))
    estimated_original = cv2.medianBlur(dct_LL, 5)
    watermark_diff = (dct_LL - estimated_original) / alpha
    watermark = cv2.resize(watermark_diff, watermark_shape)
    watermark = cv2.normalize(watermark, None, 0, 255, cv2.NORM_MINMAX)
    
    return watermark.astype(np.uint8)

def batch_extract_watermarks(input_dir, output_dir, alpha=0.05, watermark_shape=(50, 50)):
    """
    Processes all images in a directory to extract watermarks
    """
    os.makedirs(output_dir, exist_ok=True)
    frame_files = sorted([f for f in os.listdir(input_dir) if f.startswith('frame_') and f.endswith('.png')])
    watermark_accumulator = None
    valid_count = 0
    for frame_file in tqdm(frame_files, desc="Extracting watermarks"):
        try:
            frame_path = os.path.join(input_dir, frame_file)
            wm = extract_watermark_from_image(frame_path, alpha, watermark_shape)
            if watermark_accumulator is None:
                watermark_accumulator = np.zeros_like(wm, dtype=np.float32)
            watermark_accumulator += wm.astype(np.float32)
            valid_count += 1
            output_path = os.path.join(output_dir, f"extracted_{frame_file}")
            cv2.imwrite(output_path, wm)
            
        except Exception as e:
            print(f"Error processing {frame_file}: {str(e)}")
    if valid_count > 0:
        avg_watermark = (watermark_accumulator / valid_count).astype(np.uint8)
        cv2.imwrite(os.path.join(output_dir, "averaged_watermark.png"), avg_watermark)
        print(f"Successfully processed {valid_count} frames. Average watermark saved.")
    else:
        print("No valid frames processed.")

if __name__ == "__main__":
    INPUT_DIR = "./deepfaked_extracted_watermarks"  # Folder with your watermarked frames
    OUTPUT_DIR = "./deepfaked_extracted"  # Where to save extracted watermarks
    ALPHA = 0.05  # Must match your embedding strength
    WATERMARK_SHAPE = (50, 50)  # Must match your original watermark dimensions
    
    # Run extraction
    batch_extract_watermarks(INPUT_DIR, OUTPUT_DIR, ALPHA, WATERMARK_SHAPE)
# Out:
# Extracting watermarks: 100%|█████████████████████████████████████████████████████████| 469/469 [00:06<00:00, 76.90it/s]
# Successfully processed 469 frames. Average watermark saved.

# %%
Calculating the SSIM for the embeded (50*50)sized watermark before and after deepfake

# %%
import cv2
import numpy as np
import os
from skimage.metrics import structural_similarity as ssim
from tqdm import tqdm

def calculate_ssim(img1, img2):
    """Calculate SSIM between two images"""
    # Ensure images are the same size
    if img1.shape != img2.shape:
        img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))
    
    # Convert to float32 for calculation
    img1 = img1.astype(np.float32)
    img2 = img2.astype(np.float32)
    
    # Calculate SSIM (multichannel=False for grayscale)
    return ssim(img1, img2, data_range=255, full=False)

def compare_folders(generated_dir, extracted_dir):
    """Compare SSIM between corresponding images in two folders"""
    # Get sorted list of files
    gen_files = sorted([f for f in os.listdir(generated_dir) if f.endswith('.png')])
    ext_files = sorted([f for f in os.listdir(extracted_dir) if f.endswith('.png')])
    
    # Verify we have matching files
    if len(gen_files) != len(ext_files):
        print(f"Warning: Folder count mismatch - Generated: {len(gen_files)}, Extracted: {len(ext_files)}")
    
    ssim_values = []
    
    for gen_file, ext_file in tqdm(zip(gen_files, ext_files), total=min(len(gen_files), len(ext_files))):
        gen_path = os.path.join(generated_dir, gen_file)
        ext_path = os.path.join(extracted_dir, ext_file)
        
        # Load images as grayscale
        gen_img = cv2.imread(gen_path, cv2.IMREAD_GRAYSCALE)
        ext_img = cv2.imread(ext_path, cv2.IMREAD_GRAYSCALE)
        
        if gen_img is None or ext_img is None:
            print(f"Skipping {gen_file} - couldn't load one or both images")
            continue
        
        # Calculate SSIM
        current_ssim = calculate_ssim(gen_img, ext_img)
        ssim_values.append(current_ssim)
        
        print(f"{gen_file} vs {ext_file}: SSIM = {current_ssim:.4f}")
    
    if ssim_values:
        avg_ssim = np.mean(ssim_values)
        print(f"\nAverage SSIM across {len(ssim_values)} frames: {avg_ssim:.4f}")
        return avg_ssim
    else:
        print("No valid image pairs found")
        return 0

if __name__ == "__main__":
    # Configuration
    GENERATED_DIR = "./check_generated"    # Folder with watermarked images
    EXTRACTED_DIR = "./deepfaked_extracted"    # Folder with extracted watermarks
    
    # Run comparison
    average_ssim = compare_folders(GENERATED_DIR, EXTRACTED_DIR)
    
    # Save results to file
    with open("ssim_results.txt", "w") as f:
        f.write(f"Average SSIM: {average_ssim:.4f}\n")
# Out:
#   6%|████▊                                                                           | 28/470 [00:00<00:01, 270.77it/s]
# averaged_watermark.png vs averaged_watermark.png: SSIM = 0.9949
# extracted_frame_0000.png vs extracted_frame_0000.png: SSIM = 0.9768
# extracted_frame_0001.png vs extracted_frame_0001.png: SSIM = 0.9749
# extracted_frame_0002.png vs extracted_frame_0002.png: SSIM = 0.9747
# extracted_frame_0003.png vs extracted_frame_0003.png: SSIM = 0.9784
# extracted_frame_0004.png vs extracted_frame_0004.png: SSIM = 0.9763
# extracted_frame_0005.png vs extracted_frame_0005.png: SSIM = 0.9762
# extracted_frame_0006.png vs extracted_frame_0006.png: SSIM = 0.9745
# extracted_frame_0007.png vs extracted_frame_0007.png: SSIM = 0.9754
# extracted_frame_0008.png vs extracted_frame_0008.png: SSIM = 0.9743
# extracted_frame_0009.png vs extracted_frame_0009.png: SSIM = 0.9760
# extracted_frame_0010.png vs extracted_frame_0010.png: SSIM = 0.9724
# extracted_frame_0011.png vs extracted_frame_0011.png: SSIM = 0.9743
# extracted_frame_0012.png vs extracted_frame_0012.png: SSIM = 0.9747
# extracted_frame_0013.png vs extracted_frame_0013.png: SSIM = 0.9749
# extracted_frame_0014.png vs extracted_frame_0014.png: SSIM = 0.9715
# extracted_frame_0015.png vs extracted_frame_0015.png: SSIM = 0.9740
# extracted_frame_0016.png vs extracted_frame_0016.png: SSIM = 0.9755
# extracted_frame_0017.png vs extracted_frame_0017.png: SSIM = 0.9741
# extracted_frame_0018.png vs extracted_frame_0018.png: SSIM = 0.9753
# extracted_frame_0019.png vs extracted_frame_0019.png: SSIM = 0.9742
# extracted_frame_0020.png vs extracted_frame_0020.png: SSIM = 0.9722
# extracted_frame_0021.png vs extracted_frame_0021.png: SSIM = 0.9743
# extracted_frame_0022.png vs extracted_frame_0022.png: SSIM = 0.9724
# extracted_frame_0023.png vs extracted_frame_0023.png: SSIM = 0.9685
# extracted_frame_0024.png vs extracted_frame_0024.png: SSIM = 0.9718
# extracted_frame_0025.png vs extracted_frame_0025.png: SSIM = 0.9696
# extracted_frame_0026.png vs extracted_frame_0026.png: SSIM = 0.9717
# extracted_frame_0027.png vs extracted_frame_0027.png: SSIM = 0.9711
# extracted_frame_0028.png vs extracted_frame_0028.png: SSIM = 0.9711
# extracted_frame_0029.png vs extracted_frame_0029.png: SSIM = 0.9707
# extracted_frame_0030.png vs extracted_frame_0030.png: SSIM = 0.9672
# extracted_frame_0031.png vs extracted_frame_0031.png: SSIM = 0.9660
# extracted_frame_0032.png vs extracted_frame_0032.png: SSIM = 0.9652
# extracted_frame_0033.png vs extracted_frame_0033.png: SSIM = 0.9682
# extracted_frame_0034.png vs extracted_frame_0034.png: SSIM = 0.9654
# extracted_frame_0035.png vs extracted_frame_0035.png: SSIM = 0.9704
# extracted_frame_0036.png vs extracted_frame_0036.png: SSIM = 0.9694
# extracted_frame_0037.png vs extracted_frame_0037.png: SSIM = 0.9698
# extracted_frame_0038.png vs extracted_frame_0038.png: SSIM = 0.9699
# extracted_frame_0039.png vs extracted_frame_0039.png: SSIM = 0.9737
# extracted_frame_0040.png vs extracted_frame_0040.png: SSIM = 0.9732
# extracted_frame_0041.png vs extracted_frame_0041.png: SSIM = 0.9735
# extracted_frame_0042.png vs extracted_frame_0042.png: SSIM = 0.9706
# extracted_frame_0043.png vs extracted_frame_0043.png: SSIM = 0.9704
# extracted_frame_0044.png vs extracted_frame_0044.png: SSIM = 0.9747
# extracted_frame_0045.png vs extracted_frame_0045.png: SSIM = 0.9743
# extracted_frame_0046.png vs extracted_frame_0046.png: SSIM = 0.9743
# extracted_frame_0047.png vs extracted_frame_0047.png: SSIM = 0.9739
# extracted_frame_0048.png vs extracted_frame_0048.png: SSIM = 0.9767
# extracted_frame_0049.png vs extracted_frame_0049.png: SSIM = 0.9746
#  19%|███████████████▎                                                                | 90/470 [00:00<00:01, 278.61it/s]
# extracted_frame_0050.png vs extracted_frame_0050.png: SSIM = 0.9727
# extracted_frame_0051.png vs extracted_frame_0051.png: SSIM = 0.9695
# extracted_frame_0052.png vs extracted_frame_0052.png: SSIM = 0.9736
# extracted_frame_0053.png vs extracted_frame_0053.png: SSIM = 0.9738
# extracted_frame_0054.png vs extracted_frame_0054.png: SSIM = 0.9713
# extracted_frame_0055.png vs extracted_frame_0055.png: SSIM = 0.9710
# extracted_frame_0056.png vs extracted_frame_0056.png: SSIM = 0.9702
# extracted_frame_0057.png vs extracted_frame_0057.png: SSIM = 0.9700
# extracted_frame_0058.png vs extracted_frame_0058.png: SSIM = 0.9700
# extracted_frame_0059.png vs extracted_frame_0059.png: SSIM = 0.9693
# extracted_frame_0060.png vs extracted_frame_0060.png: SSIM = 0.9678
# extracted_frame_0061.png vs extracted_frame_0061.png: SSIM = 0.9687
# extracted_frame_0062.png vs extracted_frame_0062.png: SSIM = 0.9660
# extracted_frame_0063.png vs extracted_frame_0063.png: SSIM = 0.9670
# extracted_frame_0064.png vs extracted_frame_0064.png: SSIM = 0.9673
# extracted_frame_0065.png vs extracted_frame_0065.png: SSIM = 0.9651
# extracted_frame_0066.png vs extracted_frame_0066.png: SSIM = 0.9661
# extracted_frame_0067.png vs extracted_frame_0067.png: SSIM = 0.9668
# extracted_frame_0068.png vs extracted_frame_0068.png: SSIM = 0.9666
# extracted_frame_0069.png vs extracted_frame_0069.png: SSIM = 0.9695
# extracted_frame_0070.png vs extracted_frame_0070.png: SSIM = 0.9644
# extracted_frame_0071.png vs extracted_frame_0071.png: SSIM = 0.9630
# extracted_frame_0072.png vs extracted_frame_0072.png: SSIM = 0.9693
# extracted_frame_0073.png vs extracted_frame_0073.png: SSIM = 0.9636
# extracted_frame_0074.png vs extracted_frame_0074.png: SSIM = 0.9640
# extracted_frame_0075.png vs extracted_frame_0075.png: SSIM = 0.9637
# extracted_frame_0076.png vs extracted_frame_0076.png: SSIM = 0.9650
# extracted_frame_0077.png vs extracted_frame_0077.png: SSIM = 0.9650
# extracted_frame_0078.png vs extracted_frame_0078.png: SSIM = 0.9686
# extracted_frame_0079.png vs extracted_frame_0079.png: SSIM = 0.9645
# extracted_frame_0080.png vs extracted_frame_0080.png: SSIM = 0.9629
# extracted_frame_0081.png vs extracted_frame_0081.png: SSIM = 0.9620
# extracted_frame_0082.png vs extracted_frame_0082.png: SSIM = 0.9622
# extracted_frame_0083.png vs extracted_frame_0083.png: SSIM = 0.9610
# extracted_frame_0084.png vs extracted_frame_0084.png: SSIM = 0.9692
# extracted_frame_0085.png vs extracted_frame_0085.png: SSIM = 0.9661
# extracted_frame_0086.png vs extracted_frame_0086.png: SSIM = 0.9643
# extracted_frame_0087.png vs extracted_frame_0087.png: SSIM = 0.9648
# extracted_frame_0088.png vs extracted_frame_0088.png: SSIM = 0.9656
# extracted_frame_0089.png vs extracted_frame_0089.png: SSIM = 0.9672
# extracted_frame_0090.png vs extracted_frame_0090.png: SSIM = 0.9677
# extracted_frame_0091.png vs extracted_frame_0091.png: SSIM = 0.9679
# extracted_frame_0092.png vs extracted_frame_0092.png: SSIM = 0.9638
# extracted_frame_0093.png vs extracted_frame_0093.png: SSIM = 0.9666
# extracted_frame_0094.png vs extracted_frame_0094.png: SSIM = 0.9653
# extracted_frame_0095.png vs extracted_frame_0095.png: SSIM = 0.9627
# extracted_frame_0096.png vs extracted_frame_0096.png: SSIM = 0.9608
# extracted_frame_0097.png vs extracted_frame_0097.png: SSIM = 0.9602
# extracted_frame_0098.png vs extracted_frame_0098.png: SSIM = 0.9631
# extracted_frame_0099.png vs extracted_frame_0099.png: SSIM = 0.9596
# extracted_frame_0100.png vs extracted_frame_0100.png: SSIM = 0.9604
# extracted_frame_0101.png vs extracted_frame_0101.png: SSIM = 0.9599
# extracted_frame_0102.png vs extracted_frame_0102.png: SSIM = 0.9579
# extracted_frame_0103.png vs extracted_frame_0103.png: SSIM = 0.9601
# extracted_frame_0104.png vs extracted_frame_0104.png: SSIM = 0.9554
# extracted_frame_0105.png vs extracted_frame_0105.png: SSIM = 0.9534
# extracted_frame_0106.png vs extracted_frame_0106.png: SSIM = 0.9565
# extracted_frame_0107.png vs extracted_frame_0107.png: SSIM = 0.9572
# extracted_frame_0108.png vs extracted_frame_0108.png: SSIM = 0.9384
# extracted_frame_0109.png vs extracted_frame_0109.png: SSIM = 0.9537
# extracted_frame_0110.png vs extracted_frame_0110.png: SSIM = 0.9520
# extracted_frame_0111.png vs extracted_frame_0111.png: SSIM = 0.9515
# extracted_frame_0112.png vs extracted_frame_0112.png: SSIM = 0.9535
#  33%|██████████████████████████▍                                                    | 157/470 [00:00<00:01, 309.36it/s]
# extracted_frame_0113.png vs extracted_frame_0113.png: SSIM = 0.9592
# extracted_frame_0114.png vs extracted_frame_0114.png: SSIM = 0.9607
# extracted_frame_0115.png vs extracted_frame_0115.png: SSIM = 0.9592
# extracted_frame_0116.png vs extracted_frame_0116.png: SSIM = 0.9562
# extracted_frame_0117.png vs extracted_frame_0117.png: SSIM = 0.9608
# extracted_frame_0118.png vs extracted_frame_0118.png: SSIM = 0.9658
# extracted_frame_0119.png vs extracted_frame_0119.png: SSIM = 0.9661
# extracted_frame_0120.png vs extracted_frame_0120.png: SSIM = 0.9679
# extracted_frame_0121.png vs extracted_frame_0121.png: SSIM = 0.9689
# extracted_frame_0122.png vs extracted_frame_0122.png: SSIM = 0.9683
# extracted_frame_0123.png vs extracted_frame_0123.png: SSIM = 0.9682
# extracted_frame_0124.png vs extracted_frame_0124.png: SSIM = 0.9724
# extracted_frame_0125.png vs extracted_frame_0125.png: SSIM = 0.9728
# extracted_frame_0126.png vs extracted_frame_0126.png: SSIM = 0.9724
# extracted_frame_0127.png vs extracted_frame_0127.png: SSIM = 0.9728
# extracted_frame_0128.png vs extracted_frame_0128.png: SSIM = 0.9703
# extracted_frame_0129.png vs extracted_frame_0129.png: SSIM = 0.9716
# extracted_frame_0130.png vs extracted_frame_0130.png: SSIM = 0.9726
# extracted_frame_0131.png vs extracted_frame_0131.png: SSIM = 0.9697
# extracted_frame_0132.png vs extracted_frame_0132.png: SSIM = 0.9686
# extracted_frame_0133.png vs extracted_frame_0133.png: SSIM = 0.9666
# extracted_frame_0134.png vs extracted_frame_0134.png: SSIM = 0.9626
# extracted_frame_0135.png vs extracted_frame_0135.png: SSIM = 0.9696
# extracted_frame_0136.png vs extracted_frame_0136.png: SSIM = 0.9693
# extracted_frame_0137.png vs extracted_frame_0137.png: SSIM = 0.9632
# extracted_frame_0138.png vs extracted_frame_0138.png: SSIM = 0.9674
# extracted_frame_0139.png vs extracted_frame_0139.png: SSIM = 0.9693
# extracted_frame_0140.png vs extracted_frame_0140.png: SSIM = 0.9670
# extracted_frame_0141.png vs extracted_frame_0141.png: SSIM = 0.9676
# extracted_frame_0142.png vs extracted_frame_0142.png: SSIM = 0.9675
# extracted_frame_0143.png vs extracted_frame_0143.png: SSIM = 0.9680
# extracted_frame_0144.png vs extracted_frame_0144.png: SSIM = 0.9645
# extracted_frame_0145.png vs extracted_frame_0145.png: SSIM = 0.9608
# extracted_frame_0146.png vs extracted_frame_0146.png: SSIM = 0.9579
# extracted_frame_0147.png vs extracted_frame_0147.png: SSIM = 0.9631
# extracted_frame_0148.png vs extracted_frame_0148.png: SSIM = 0.9719
# extracted_frame_0149.png vs extracted_frame_0149.png: SSIM = 0.9663
# extracted_frame_0150.png vs extracted_frame_0150.png: SSIM = 0.9669
# extracted_frame_0151.png vs extracted_frame_0151.png: SSIM = 0.9647
# extracted_frame_0152.png vs extracted_frame_0152.png: SSIM = 0.9620
# extracted_frame_0153.png vs extracted_frame_0153.png: SSIM = 0.9646
# extracted_frame_0154.png vs extracted_frame_0154.png: SSIM = 0.9611
# extracted_frame_0155.png vs extracted_frame_0155.png: SSIM = 0.9609
# extracted_frame_0156.png vs extracted_frame_0156.png: SSIM = 0.9627
# extracted_frame_0157.png vs extracted_frame_0157.png: SSIM = 0.9623
# extracted_frame_0158.png vs extracted_frame_0158.png: SSIM = 0.9615
# extracted_frame_0159.png vs extracted_frame_0159.png: SSIM = 0.9591
# extracted_frame_0160.png vs extracted_frame_0160.png: SSIM = 0.9578
# extracted_frame_0161.png vs extracted_frame_0161.png: SSIM = 0.9595
# extracted_frame_0162.png vs extracted_frame_0162.png: SSIM = 0.9604
# extracted_frame_0163.png vs extracted_frame_0163.png: SSIM = 0.9577
# extracted_frame_0164.png vs extracted_frame_0164.png: SSIM = 0.9601
# extracted_frame_0165.png vs extracted_frame_0165.png: SSIM = 0.9553
# extracted_frame_0166.png vs extracted_frame_0166.png: SSIM = 0.9576
# extracted_frame_0167.png vs extracted_frame_0167.png: SSIM = 0.9558
# extracted_frame_0168.png vs extracted_frame_0168.png: SSIM = 0.9634
# extracted_frame_0169.png vs extracted_frame_0169.png: SSIM = 0.9670
# extracted_frame_0170.png vs extracted_frame_0170.png: SSIM = 0.9629
# extracted_frame_0171.png vs extracted_frame_0171.png: SSIM = 0.9625
# extracted_frame_0172.png vs extracted_frame_0172.png: SSIM = 0.9651
# extracted_frame_0173.png vs extracted_frame_0173.png: SSIM = 0.9626
# extracted_frame_0174.png vs extracted_frame_0174.png: SSIM = 0.9603
# extracted_frame_0175.png vs extracted_frame_0175.png: SSIM = 0.9619
# extracted_frame_0176.png vs extracted_frame_0176.png: SSIM = 0.9627
# extracted_frame_0177.png vs extracted_frame_0177.png: SSIM = 0.9612
# extracted_frame_0178.png vs extracted_frame_0178.png: SSIM = 0.9626
# extracted_frame_0179.png vs extracted_frame_0179.png: SSIM = 0.9645
# extracted_frame_0180.png vs extracted_frame_0180.png: SSIM = 0.9541
# extracted_frame_0181.png vs extracted_frame_0181.png: SSIM = 0.9565
# extracted_frame_0182.png vs extracted_frame_0182.png: SSIM = 0.9591
#  47%|████████████████████████████████████▊                                          | 219/470 [00:00<00:00, 274.06it/s]
# extracted_frame_0183.png vs extracted_frame_0183.png: SSIM = 0.9568
# extracted_frame_0184.png vs extracted_frame_0184.png: SSIM = 0.9508
# extracted_frame_0185.png vs extracted_frame_0185.png: SSIM = 0.9484
# extracted_frame_0186.png vs extracted_frame_0186.png: SSIM = 0.9491
# extracted_frame_0187.png vs extracted_frame_0187.png: SSIM = 0.9521
# extracted_frame_0188.png vs extracted_frame_0188.png: SSIM = 0.9464
# extracted_frame_0189.png vs extracted_frame_0189.png: SSIM = 0.9332
# extracted_frame_0190.png vs extracted_frame_0190.png: SSIM = 0.9458
# extracted_frame_0191.png vs extracted_frame_0191.png: SSIM = 0.9485
# extracted_frame_0192.png vs extracted_frame_0192.png: SSIM = 0.9556
# extracted_frame_0193.png vs extracted_frame_0193.png: SSIM = 0.9512
# extracted_frame_0194.png vs extracted_frame_0194.png: SSIM = 0.9516
# extracted_frame_0195.png vs extracted_frame_0195.png: SSIM = 0.9518
# extracted_frame_0196.png vs extracted_frame_0196.png: SSIM = 0.9554
# extracted_frame_0197.png vs extracted_frame_0197.png: SSIM = 0.9425
# extracted_frame_0198.png vs extracted_frame_0198.png: SSIM = 0.9494
# extracted_frame_0199.png vs extracted_frame_0199.png: SSIM = 0.9445
# extracted_frame_0200.png vs extracted_frame_0200.png: SSIM = 0.9484
# extracted_frame_0201.png vs extracted_frame_0201.png: SSIM = 0.9521
# extracted_frame_0202.png vs extracted_frame_0202.png: SSIM = 0.9543
# extracted_frame_0203.png vs extracted_frame_0203.png: SSIM = 0.9575
# extracted_frame_0204.png vs extracted_frame_0204.png: SSIM = 0.9488
# extracted_frame_0205.png vs extracted_frame_0205.png: SSIM = 0.9509
# extracted_frame_0206.png vs extracted_frame_0206.png: SSIM = 0.9516
# extracted_frame_0207.png vs extracted_frame_0207.png: SSIM = 0.9550
# extracted_frame_0208.png vs extracted_frame_0208.png: SSIM = 0.9397
# extracted_frame_0209.png vs extracted_frame_0209.png: SSIM = 0.9501
# extracted_frame_0210.png vs extracted_frame_0210.png: SSIM = 0.9508
# extracted_frame_0211.png vs extracted_frame_0211.png: SSIM = 0.9492
# extracted_frame_0212.png vs extracted_frame_0212.png: SSIM = 0.9398
# extracted_frame_0213.png vs extracted_frame_0213.png: SSIM = 0.9373
# extracted_frame_0214.png vs extracted_frame_0214.png: SSIM = 0.9374
# extracted_frame_0215.png vs extracted_frame_0215.png: SSIM = 0.9356
# extracted_frame_0216.png vs extracted_frame_0216.png: SSIM = 0.9425
# extracted_frame_0217.png vs extracted_frame_0217.png: SSIM = 0.9394
# extracted_frame_0218.png vs extracted_frame_0218.png: SSIM = 0.9394
# extracted_frame_0219.png vs extracted_frame_0219.png: SSIM = 0.9388
# extracted_frame_0220.png vs extracted_frame_0220.png: SSIM = 0.9464
# extracted_frame_0221.png vs extracted_frame_0221.png: SSIM = 0.9480
# extracted_frame_0222.png vs extracted_frame_0222.png: SSIM = 0.9570
# extracted_frame_0223.png vs extracted_frame_0223.png: SSIM = 0.9593
# extracted_frame_0224.png vs extracted_frame_0224.png: SSIM = 0.8997
# extracted_frame_0225.png vs extracted_frame_0225.png: SSIM = 0.8971
# extracted_frame_0226.png vs extracted_frame_0226.png: SSIM = 0.9220
# extracted_frame_0227.png vs extracted_frame_0227.png: SSIM = 0.9245
#  61%|███████████████████████████████████████████████▉                               | 285/470 [00:00<00:00, 291.91it/s]
# extracted_frame_0228.png vs extracted_frame_0228.png: SSIM = 0.9352
# extracted_frame_0229.png vs extracted_frame_0229.png: SSIM = 0.9301
# extracted_frame_0230.png vs extracted_frame_0230.png: SSIM = 0.9279
# extracted_frame_0231.png vs extracted_frame_0231.png: SSIM = 0.9273
# extracted_frame_0232.png vs extracted_frame_0232.png: SSIM = 0.9400
# extracted_frame_0233.png vs extracted_frame_0233.png: SSIM = 0.9545
# extracted_frame_0234.png vs extracted_frame_0234.png: SSIM = 0.9324
# extracted_frame_0235.png vs extracted_frame_0235.png: SSIM = 0.9131
# extracted_frame_0236.png vs extracted_frame_0236.png: SSIM = 0.9459
# extracted_frame_0237.png vs extracted_frame_0237.png: SSIM = 0.9446
# extracted_frame_0238.png vs extracted_frame_0238.png: SSIM = 0.9335
# extracted_frame_0239.png vs extracted_frame_0239.png: SSIM = 0.9401
# extracted_frame_0240.png vs extracted_frame_0240.png: SSIM = 0.9506
# extracted_frame_0241.png vs extracted_frame_0241.png: SSIM = 0.9518
# extracted_frame_0242.png vs extracted_frame_0242.png: SSIM = 0.9478
# extracted_frame_0243.png vs extracted_frame_0243.png: SSIM = 0.9492
# extracted_frame_0244.png vs extracted_frame_0244.png: SSIM = 0.9562
# extracted_frame_0245.png vs extracted_frame_0245.png: SSIM = 0.9503
# extracted_frame_0246.png vs extracted_frame_0246.png: SSIM = 0.9466
# extracted_frame_0247.png vs extracted_frame_0247.png: SSIM = 0.9503
# extracted_frame_0248.png vs extracted_frame_0248.png: SSIM = 0.9529
# extracted_frame_0249.png vs extracted_frame_0249.png: SSIM = 0.9522
# extracted_frame_0250.png vs extracted_frame_0250.png: SSIM = 0.9614
# extracted_frame_0251.png vs extracted_frame_0251.png: SSIM = 0.9538
# extracted_frame_0252.png vs extracted_frame_0252.png: SSIM = 0.9556
# extracted_frame_0253.png vs extracted_frame_0253.png: SSIM = 0.9637
# extracted_frame_0254.png vs extracted_frame_0254.png: SSIM = 0.9562
# extracted_frame_0255.png vs extracted_frame_0255.png: SSIM = 0.9579
# extracted_frame_0256.png vs extracted_frame_0256.png: SSIM = 0.9490
# extracted_frame_0257.png vs extracted_frame_0257.png: SSIM = 0.9581
# extracted_frame_0258.png vs extracted_frame_0258.png: SSIM = 0.9545
# extracted_frame_0259.png vs extracted_frame_0259.png: SSIM = 0.9541
# extracted_frame_0260.png vs extracted_frame_0260.png: SSIM = 0.9403
# extracted_frame_0261.png vs extracted_frame_0261.png: SSIM = 0.9449
# extracted_frame_0262.png vs extracted_frame_0262.png: SSIM = 0.9462
# extracted_frame_0263.png vs extracted_frame_0263.png: SSIM = 0.9539
# extracted_frame_0264.png vs extracted_frame_0264.png: SSIM = 0.9538
# extracted_frame_0265.png vs extracted_frame_0265.png: SSIM = 0.9583
# extracted_frame_0266.png vs extracted_frame_0266.png: SSIM = 0.9615
# extracted_frame_0267.png vs extracted_frame_0267.png: SSIM = 0.9598
# extracted_frame_0268.png vs extracted_frame_0268.png: SSIM = 0.9591
# extracted_frame_0269.png vs extracted_frame_0269.png: SSIM = 0.9569
# extracted_frame_0270.png vs extracted_frame_0270.png: SSIM = 0.9464
# extracted_frame_0271.png vs extracted_frame_0271.png: SSIM = 0.9052
# extracted_frame_0272.png vs extracted_frame_0272.png: SSIM = 0.9299
# extracted_frame_0273.png vs extracted_frame_0273.png: SSIM = 0.9308
# extracted_frame_0274.png vs extracted_frame_0274.png: SSIM = 0.9222
# extracted_frame_0275.png vs extracted_frame_0275.png: SSIM = 0.9230
# extracted_frame_0276.png vs extracted_frame_0276.png: SSIM = 0.9303
# extracted_frame_0277.png vs extracted_frame_0277.png: SSIM = 0.9200
# extracted_frame_0278.png vs extracted_frame_0278.png: SSIM = 0.9114
# extracted_frame_0279.png vs extracted_frame_0279.png: SSIM = 0.8942
# extracted_frame_0280.png vs extracted_frame_0280.png: SSIM = 0.9111
# extracted_frame_0281.png vs extracted_frame_0281.png: SSIM = 0.9211
# extracted_frame_0282.png vs extracted_frame_0282.png: SSIM = 0.9167
# extracted_frame_0283.png vs extracted_frame_0283.png: SSIM = 0.9290
# extracted_frame_0284.png vs extracted_frame_0284.png: SSIM = 0.9416
# extracted_frame_0285.png vs extracted_frame_0285.png: SSIM = 0.9430
# extracted_frame_0286.png vs extracted_frame_0286.png: SSIM = 0.9423
# extracted_frame_0287.png vs extracted_frame_0287.png: SSIM = 0.9402
# extracted_frame_0288.png vs extracted_frame_0288.png: SSIM = 0.9561
# extracted_frame_0289.png vs extracted_frame_0289.png: SSIM = 0.9571
# extracted_frame_0290.png vs extracted_frame_0290.png: SSIM = 0.9588
#  67%|████████████████████████████████████████████████████▉                          | 315/470 [00:01<00:00, 281.03it/s]
# extracted_frame_0291.png vs extracted_frame_0291.png: SSIM = 0.9579
# extracted_frame_0292.png vs extracted_frame_0292.png: SSIM = 0.9601
# extracted_frame_0293.png vs extracted_frame_0293.png: SSIM = 0.9587
# extracted_frame_0294.png vs extracted_frame_0294.png: SSIM = 0.9598
# extracted_frame_0295.png vs extracted_frame_0295.png: SSIM = 0.9554
# extracted_frame_0296.png vs extracted_frame_0296.png: SSIM = 0.9551
# extracted_frame_0297.png vs extracted_frame_0297.png: SSIM = 0.9487
# extracted_frame_0298.png vs extracted_frame_0298.png: SSIM = 0.9512
# extracted_frame_0299.png vs extracted_frame_0299.png: SSIM = 0.9509
# extracted_frame_0300.png vs extracted_frame_0300.png: SSIM = 0.9627
# extracted_frame_0301.png vs extracted_frame_0301.png: SSIM = 0.9636
# extracted_frame_0302.png vs extracted_frame_0302.png: SSIM = 0.9657
# extracted_frame_0303.png vs extracted_frame_0303.png: SSIM = 0.9645
# extracted_frame_0304.png vs extracted_frame_0304.png: SSIM = 0.9681
# extracted_frame_0305.png vs extracted_frame_0305.png: SSIM = 0.9657
# extracted_frame_0306.png vs extracted_frame_0306.png: SSIM = 0.9668
# extracted_frame_0307.png vs extracted_frame_0307.png: SSIM = 0.9688
# extracted_frame_0308.png vs extracted_frame_0308.png: SSIM = 0.9671
# extracted_frame_0309.png vs extracted_frame_0309.png: SSIM = 0.9680
# extracted_frame_0310.png vs extracted_frame_0310.png: SSIM = 0.9705
# extracted_frame_0311.png vs extracted_frame_0311.png: SSIM = 0.9711
# extracted_frame_0312.png vs extracted_frame_0312.png: SSIM = 0.9699
# extracted_frame_0313.png vs extracted_frame_0313.png: SSIM = 0.9664
# extracted_frame_0314.png vs extracted_frame_0314.png: SSIM = 0.9676
# extracted_frame_0315.png vs extracted_frame_0315.png: SSIM = 0.9660
# extracted_frame_0316.png vs extracted_frame_0316.png: SSIM = 0.9628
# extracted_frame_0317.png vs extracted_frame_0317.png: SSIM = 0.9657
# extracted_frame_0318.png vs extracted_frame_0318.png: SSIM = 0.9689
# extracted_frame_0319.png vs extracted_frame_0319.png: SSIM = 0.9715
# extracted_frame_0320.png vs extracted_frame_0320.png: SSIM = 0.9718
# extracted_frame_0321.png vs extracted_frame_0321.png: SSIM = 0.9703
# extracted_frame_0322.png vs extracted_frame_0322.png: SSIM = 0.9732
# extracted_frame_0323.png vs extracted_frame_0323.png: SSIM = 0.9708
# extracted_frame_0324.png vs extracted_frame_0324.png: SSIM = 0.9774
# extracted_frame_0325.png vs extracted_frame_0325.png: SSIM = 0.9771
# extracted_frame_0326.png vs extracted_frame_0326.png: SSIM = 0.9759
# extracted_frame_0327.png vs extracted_frame_0327.png: SSIM = 0.9765
# extracted_frame_0328.png vs extracted_frame_0328.png: SSIM = 0.9755
# extracted_frame_0329.png vs extracted_frame_0329.png: SSIM = 0.9733
# extracted_frame_0330.png vs extracted_frame_0330.png: SSIM = 0.9724
# extracted_frame_0331.png vs extracted_frame_0331.png: SSIM = 0.9735
# extracted_frame_0332.png vs extracted_frame_0332.png: SSIM = 0.9721
# extracted_frame_0333.png vs extracted_frame_0333.png: SSIM = 0.9712
# extracted_frame_0334.png vs extracted_frame_0334.png: SSIM = 0.9719
#  80%|███████████████████████████████████████████████████████████████▎               | 377/470 [00:01<00:00, 285.51it/s]
# extracted_frame_0335.png vs extracted_frame_0335.png: SSIM = 0.9687
# extracted_frame_0336.png vs extracted_frame_0336.png: SSIM = 0.9721
# extracted_frame_0337.png vs extracted_frame_0337.png: SSIM = 0.9749
# extracted_frame_0338.png vs extracted_frame_0338.png: SSIM = 0.9735
# extracted_frame_0339.png vs extracted_frame_0339.png: SSIM = 0.9761
# extracted_frame_0340.png vs extracted_frame_0340.png: SSIM = 0.9749
# extracted_frame_0341.png vs extracted_frame_0341.png: SSIM = 0.9774
# extracted_frame_0342.png vs extracted_frame_0342.png: SSIM = 0.9724
# extracted_frame_0343.png vs extracted_frame_0343.png: SSIM = 0.9755
# extracted_frame_0344.png vs extracted_frame_0344.png: SSIM = 0.9749
# extracted_frame_0345.png vs extracted_frame_0345.png: SSIM = 0.9740
# extracted_frame_0346.png vs extracted_frame_0346.png: SSIM = 0.9741
# extracted_frame_0347.png vs extracted_frame_0347.png: SSIM = 0.9757
# extracted_frame_0348.png vs extracted_frame_0348.png: SSIM = 0.9692
# extracted_frame_0349.png vs extracted_frame_0349.png: SSIM = 0.9691
# extracted_frame_0350.png vs extracted_frame_0350.png: SSIM = 0.9734
# extracted_frame_0351.png vs extracted_frame_0351.png: SSIM = 0.9718
# extracted_frame_0352.png vs extracted_frame_0352.png: SSIM = 0.9717
# extracted_frame_0353.png vs extracted_frame_0353.png: SSIM = 0.9743
# extracted_frame_0354.png vs extracted_frame_0354.png: SSIM = 0.9760
# extracted_frame_0355.png vs extracted_frame_0355.png: SSIM = 0.9780
# extracted_frame_0356.png vs extracted_frame_0356.png: SSIM = 0.9765
# extracted_frame_0357.png vs extracted_frame_0357.png: SSIM = 0.9811
# extracted_frame_0358.png vs extracted_frame_0358.png: SSIM = 0.9801
# extracted_frame_0359.png vs extracted_frame_0359.png: SSIM = 0.9816
# extracted_frame_0360.png vs extracted_frame_0360.png: SSIM = 0.9830
# extracted_frame_0361.png vs extracted_frame_0361.png: SSIM = 0.9838
# extracted_frame_0362.png vs extracted_frame_0362.png: SSIM = 0.9831
# extracted_frame_0363.png vs extracted_frame_0363.png: SSIM = 0.9836
# extracted_frame_0364.png vs extracted_frame_0364.png: SSIM = 0.9820
# extracted_frame_0365.png vs extracted_frame_0365.png: SSIM = 0.9813
# extracted_frame_0366.png vs extracted_frame_0366.png: SSIM = 0.9838
# extracted_frame_0367.png vs extracted_frame_0367.png: SSIM = 0.9827
# extracted_frame_0368.png vs extracted_frame_0368.png: SSIM = 0.9833
# extracted_frame_0369.png vs extracted_frame_0369.png: SSIM = 0.9846
# extracted_frame_0370.png vs extracted_frame_0370.png: SSIM = 0.9833
# extracted_frame_0371.png vs extracted_frame_0371.png: SSIM = 0.9849
# extracted_frame_0372.png vs extracted_frame_0372.png: SSIM = 0.9884
# extracted_frame_0373.png vs extracted_frame_0373.png: SSIM = 0.9871
# extracted_frame_0374.png vs extracted_frame_0374.png: SSIM = 0.9862
# extracted_frame_0375.png vs extracted_frame_0375.png: SSIM = 0.9866
# extracted_frame_0376.png vs extracted_frame_0376.png: SSIM = 0.9849
# extracted_frame_0377.png vs extracted_frame_0377.png: SSIM = 0.9840
# extracted_frame_0378.png vs extracted_frame_0378.png: SSIM = 0.9828
# extracted_frame_0379.png vs extracted_frame_0379.png: SSIM = 0.9843
# extracted_frame_0380.png vs extracted_frame_0380.png: SSIM = 0.9835
# extracted_frame_0381.png vs extracted_frame_0381.png: SSIM = 0.9848
# extracted_frame_0382.png vs extracted_frame_0382.png: SSIM = 0.9850
# extracted_frame_0383.png vs extracted_frame_0383.png: SSIM = 0.9832
# extracted_frame_0384.png vs extracted_frame_0384.png: SSIM = 0.9819
# extracted_frame_0385.png vs extracted_frame_0385.png: SSIM = 0.9836
# extracted_frame_0386.png vs extracted_frame_0386.png: SSIM = 0.9853
# extracted_frame_0387.png vs extracted_frame_0387.png: SSIM = 0.9845
# extracted_frame_0388.png vs extracted_frame_0388.png: SSIM = 0.9820
# extracted_frame_0389.png vs extracted_frame_0389.png: SSIM = 0.9828
# extracted_frame_0390.png vs extracted_frame_0390.png: SSIM = 0.9834
# extracted_frame_0391.png vs extracted_frame_0391.png: SSIM = 0.9810
# extracted_frame_0392.png vs extracted_frame_0392.png: SSIM = 0.9822
# extracted_frame_0393.png vs extracted_frame_0393.png: SSIM = 0.9828
# extracted_frame_0394.png vs extracted_frame_0394.png: SSIM = 0.9822
# extracted_frame_0395.png vs extracted_frame_0395.png: SSIM = 0.9781
# extracted_frame_0396.png vs extracted_frame_0396.png: SSIM = 0.9797
# extracted_frame_0397.png vs extracted_frame_0397.png: SSIM = 0.9802
# extracted_frame_0398.png vs extracted_frame_0398.png: SSIM = 0.9805
# extracted_frame_0399.png vs extracted_frame_0399.png: SSIM = 0.9764
# extracted_frame_0400.png vs extracted_frame_0400.png: SSIM = 0.9765
# extracted_frame_0401.png vs extracted_frame_0401.png: SSIM = 0.9780
# extracted_frame_0402.png vs extracted_frame_0402.png: SSIM = 0.9801
# extracted_frame_0403.png vs extracted_frame_0403.png: SSIM = 0.9759
# extracted_frame_0404.png vs extracted_frame_0404.png: SSIM = 0.9791
# extracted_frame_0405.png vs extracted_frame_0405.png: SSIM = 0.9761
# extracted_frame_0406.png vs extracted_frame_0406.png: SSIM = 0.9731
#  94%|█████████████████████████████████████████████████████████████████████████▉     | 440/470 [00:01<00:00, 285.65it/s]
# extracted_frame_0407.png vs extracted_frame_0407.png: SSIM = 0.9728
# extracted_frame_0408.png vs extracted_frame_0408.png: SSIM = 0.9721
# extracted_frame_0409.png vs extracted_frame_0409.png: SSIM = 0.9695
# extracted_frame_0410.png vs extracted_frame_0410.png: SSIM = 0.9673
# extracted_frame_0411.png vs extracted_frame_0411.png: SSIM = 0.9698
# extracted_frame_0412.png vs extracted_frame_0412.png: SSIM = 0.9656
# extracted_frame_0413.png vs extracted_frame_0413.png: SSIM = 0.9673
# extracted_frame_0414.png vs extracted_frame_0414.png: SSIM = 0.9627
# extracted_frame_0415.png vs extracted_frame_0415.png: SSIM = 0.9742
# extracted_frame_0416.png vs extracted_frame_0416.png: SSIM = 0.9688
# extracted_frame_0417.png vs extracted_frame_0417.png: SSIM = 0.9685
# extracted_frame_0418.png vs extracted_frame_0418.png: SSIM = 0.9666
# extracted_frame_0419.png vs extracted_frame_0419.png: SSIM = 0.9671
# extracted_frame_0420.png vs extracted_frame_0420.png: SSIM = 0.9678
# extracted_frame_0421.png vs extracted_frame_0421.png: SSIM = 0.9639
# extracted_frame_0422.png vs extracted_frame_0422.png: SSIM = 0.9675
# extracted_frame_0423.png vs extracted_frame_0423.png: SSIM = 0.9700
# extracted_frame_0424.png vs extracted_frame_0424.png: SSIM = 0.9713
# extracted_frame_0425.png vs extracted_frame_0425.png: SSIM = 0.9712
# extracted_frame_0426.png vs extracted_frame_0426.png: SSIM = 0.9693
# extracted_frame_0427.png vs extracted_frame_0427.png: SSIM = 0.9684
# extracted_frame_0428.png vs extracted_frame_0428.png: SSIM = 0.9693
# extracted_frame_0429.png vs extracted_frame_0429.png: SSIM = 0.9692
# extracted_frame_0430.png vs extracted_frame_0430.png: SSIM = 0.9666
# extracted_frame_0431.png vs extracted_frame_0431.png: SSIM = 0.9685
# extracted_frame_0432.png vs extracted_frame_0432.png: SSIM = 0.9738
# extracted_frame_0433.png vs extracted_frame_0433.png: SSIM = 0.9720
# extracted_frame_0434.png vs extracted_frame_0434.png: SSIM = 0.9712
# extracted_frame_0435.png vs extracted_frame_0435.png: SSIM = 0.9709
# extracted_frame_0436.png vs extracted_frame_0436.png: SSIM = 0.9723
# extracted_frame_0437.png vs extracted_frame_0437.png: SSIM = 0.9713
# extracted_frame_0438.png vs extracted_frame_0438.png: SSIM = 0.9719
# extracted_frame_0439.png vs extracted_frame_0439.png: SSIM = 0.9709
# extracted_frame_0440.png vs extracted_frame_0440.png: SSIM = 0.9699
# extracted_frame_0441.png vs extracted_frame_0441.png: SSIM = 0.9632
# extracted_frame_0442.png vs extracted_frame_0442.png: SSIM = 0.9640
# extracted_frame_0443.png vs extracted_frame_0443.png: SSIM = 0.9610
# extracted_frame_0444.png vs extracted_frame_0444.png: SSIM = 0.9678
# extracted_frame_0445.png vs extracted_frame_0445.png: SSIM = 0.9679
# extracted_frame_0446.png vs extracted_frame_0446.png: SSIM = 0.9671
# extracted_frame_0447.png vs extracted_frame_0447.png: SSIM = 0.9653
# extracted_frame_0448.png vs extracted_frame_0448.png: SSIM = 0.9636
# extracted_frame_0449.png vs extracted_frame_0449.png: SSIM = 0.9591
# extracted_frame_0450.png vs extracted_frame_0450.png: SSIM = 0.9556
# extracted_frame_0451.png vs extracted_frame_0451.png: SSIM = 0.9547
# extracted_frame_0452.png vs extracted_frame_0452.png: SSIM = 0.9538
# extracted_frame_0453.png vs extracted_frame_0453.png: SSIM = 0.9539
# extracted_frame_0454.png vs extracted_frame_0454.png: SSIM = 0.9525
# extracted_frame_0455.png vs extracted_frame_0455.png: SSIM = 0.9542
# extracted_frame_0456.png vs extracted_frame_0456.png: SSIM = 0.9626
# extracted_frame_0457.png vs extracted_frame_0457.png: SSIM = 0.9598
# extracted_frame_0458.png vs extracted_frame_0458.png: SSIM = 0.9567
# extracted_frame_0459.png vs extracted_frame_0459.png: SSIM = 0.9602
# extracted_frame_0460.png vs extracted_frame_0460.png: SSIM = 0.9572
# extracted_frame_0461.png vs extracted_frame_0461.png: SSIM = 0.9567
# 100%|███████████████████████████████████████████████████████████████████████████████| 470/470 [00:01<00:00, 283.75it/s]
# extracted_frame_0462.png vs extracted_frame_0462.png: SSIM = 0.9488
# extracted_frame_0463.png vs extracted_frame_0463.png: SSIM = 0.9495
# extracted_frame_0464.png vs extracted_frame_0464.png: SSIM = 0.9470
# extracted_frame_0465.png vs extracted_frame_0465.png: SSIM = 0.9558
# extracted_frame_0466.png vs extracted_frame_0466.png: SSIM = 0.9513
# extracted_frame_0467.png vs extracted_frame_0467.png: SSIM = 0.9501
# extracted_frame_0468.png vs extracted_frame_0468.png: SSIM = 0.9573
#
# Average SSIM across 470 frames: 0.9629
